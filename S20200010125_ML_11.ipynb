# %%
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
tree, types = mnist.load_data()

# %%
x_tree = tree[0]
y_tree = tree[1]
x_types = types[0]
y_types = types[1]

# %%
i=4
plt.imshow(x_tree[i])

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.models import Sequential

# %%
copy = Sequential([
        Flatten(input_shape=(28,28)),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(10, activation='softmax'),
    ])

copy.compile(optimizer = 'adam',
              loss='SparseCategoricalCrossentropy', metrics=['accuracy'])
history = copy.fit(x_tree, y_tree, validation_split=0.2, epochs=20, verbose=1)
copy.evaluate(x_types, y_types)
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 5s 3ms/step - loss: 1.7886 - accuracy: 0.7573 - val_loss: 0.5084 - val_accuracy: 0.8838
# Epoch 2/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.4428 - accuracy: 0.8850 - val_loss: 0.3804 - val_accuracy: 0.9044
# Epoch 3/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3174 - accuracy: 0.9165 - val_loss: 0.3166 - val_accuracy: 0.9240
# Epoch 4/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2460 - accuracy: 0.9331 - val_loss: 0.2462 - val_accuracy: 0.9417
# Epoch 5/20
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.2074 - accuracy: 0.9429 - val_loss: 0.2177 - val_accuracy: 0.9424
# Epoch 6/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1816 - accuracy: 0.9499 - val_loss: 0.2161 - val_accuracy: 0.9441
# Epoch 7/20
# ...

# %%
perfect = [0.001,0.003,0.006,0.008,0.01]

# %%
def plan(history):
    plt.figure(facecolor='grey')
    l1 = plt.plot(history.history['loss'])
    l2 = plt.plot(history.history['val_loss'])
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    labels = ["Loss", "Validation Loss"]
    plt.legend([l1, l2], labels=labels,
           loc="upper right")

# %%
def MD_Ke():
        copy = Sequential([
        Flatten(input_shape=(28,28)),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(10, activation='softmax'),
    ])
        return copy

# %%
def attach(lr):
    copy = MD_Ke()
    copy.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=lr),
                  loss='SparseCategoricalCrossentropy', metrics=['accuracy'])
    history = copy.fit(x_tree, y_tree, validation_split=0.2, epochs=20, verbose=1)
    copy.evaluate(x_types, y_types)
    return history

# %%
history = []
for i in range(len(perfect)):
    history.append(attach(perfect[i]))
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 2.0391 - accuracy: 0.6194 - val_loss: 0.7603 - val_accuracy: 0.7906
# Epoch 2/20
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.6528 - accuracy: 0.8061 - val_loss: 0.6761 - val_accuracy: 0.8267
# Epoch 3/20
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.4580 - accuracy: 0.8683 - val_loss: 0.4124 - val_accuracy: 0.9000
# Epoch 4/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3148 - accuracy: 0.9198 - val_loss: 0.2818 - val_accuracy: 0.9267
# Epoch 5/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.2468 - accuracy: 0.9360 - val_loss: 0.2424 - val_accuracy: 0.9424
# Epoch 6/20
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.1963 - accuracy: 0.9468 - val_loss: 0.2260 - val_accuracy: 0.9451
# Epoch 7/20
# ...

# %%
for i in range(len(history)):
    plan(history[i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   if __name__ == '__main__':
